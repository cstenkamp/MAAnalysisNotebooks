# %%
import os
from os.path import join, isdir, isfile, abspath, dirname, splitext, basename, split

from IPython.display import Markdown, display
from dotenv import load_dotenv
import numpy as np
import pandas as pd

from misc_util.pretty_print import pretty_print as print
from derive_conceptualspace.pipeline import CustomContext, SnakeContext, load_envfiles
from derive_conceptualspace.settings import ENV_PREFIX, get_setting

from misc_util.logutils import setup_logging
from misc_util.pretty_print import display, pretty_print as print
from derive_conceptualspace.util.threedfigure import ThreeDFigure
from derive_conceptualspace.semantic_directions.cluster_names import get_name_dict
from derive_conceptualspace.pipeline import SnakeContext, load_envfiles, cluster_loader
from derive_conceptualspace.util.result_analysis_tools import getfiles_allconfigs
from derive_conceptualspace.util.desc_object import DescriptionList
from derive_conceptualspace.evaluate.shallow_trees import classify_shallowtree

pd.options.display.float_format = '{:.3f}'.format
# Out:
# 2022-04-12 10:41:22.518825: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/chris/Documents/JOBS/Uhrig-Gesture-Recog/skelshop_deps/openpose_cpu/build/src/openpose/
# 2022-04-12 10:41:22.518857: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# <span style="font-size:11pt"></span>

# %% [markdown]
# ## Analysis of different "measures of faithfulness of the separation"

# %%
setup_logging()
load_envfiles("siddata")
configs, print_cnf = getfiles_allconfigs("featureaxes", verbose=True)
# Out:
# <span style="font-size:11pt">There are 36 different parameter-combis for dataset <span style="color: #0000ff">siddata2022</span>:</span>
# {'dataset': 'siddata2022',
#  'language': 'de',
#  'debug': 'False',
#  'pp_components': ['mfauhcsd2', 'mfauhtcsldp'],
#  'translate_policy': 'onlyorig',
#  'min_words_per_desc': '80',
#  'quantification_measure': ['ppmi', 'tfidf'],
#  'embed_algo': 'mds',
#  'embed_dimensions': ['3', '50', '200'],
#  'extraction_method': 'tfidf',
#  'dcm_quant_measure': ['count', 'ppmi', 'tfidf'],
#  'kappa_weights': 'quadratic'}

# %%
configs = [c for c in configs if c["embed_dimensions"] != 3]
cnf = {'pp_components': 'mfauhcsd2', 'quantification_measure': 'tfidf', 'embed_dimensions': '200', 'dcm_quant_measure': 'count', 'classifier_succmetric': 'kappa_digitized_onlypos_2', 'sec_lambda': '0.2'}

# %%
sample_ctx = SnakeContext.loader_context(config=cnf) #dict(debug=False, min_words_per_desc=80, dcm_quant_measure="count")
descriptions, dcm, embedding, featureaxes = sample_ctx.load("pp_descriptions", "filtered_dcm", "embedding", "featureaxes")
dcm.show_info(descriptions=descriptions)
# Out:
# <span style="font-size:11pt">conf_file demanded config QUANTIFICATION_MEASURE to be <span style="color: #ff0000">ppmi</span>, but force overwrites it to <span style="color: #0000ff">tfidf</span></span>
# <span style="font-size:11pt">conf_file demanded config EMBED_DIMENSIONS to be <span style="color: #ff0000">50</span>, but force overwrites it to <span style="color: #0000ff">200</span></span>
# <span style="font-size:11pt">conf_file demanded config CLASSIFIER_SUCCMETRIC to be <span style="color: #ff0000">kappa_rank2rank_onlypos_min</span>, but force overwrites it to <span style="color: #0000ff">kappa_digitized_onlypos_2</span></span>
# <span style="font-size:11pt">conf_file demanded config SEC_LAMBDA to be <span style="color: #ff0000">0.1</span>, but force overwrites it to <span style="color: #0000ff">0.2</span></span>
# <span style="font-size:11pt">Config-File /home/chris/Documents/UNI_neu/Masterarbeit/Derive_Conceptualspace/config/derrac2015_edited.yml loaded.</span>
# <span style="font-size:11pt">Debug is active! #Items for Debug: 500</span>
# <span style="font-size:11pt">Using a random seed: 1</span>
# <span style="font-size:11pt">Running with the following settings [<span style="color: #009999">3ef8af7b39</span>]: CANDIDATE_MIN_TERM_COUNT: <span style="color: #ff0000">2</span>, CLASSIFIER: <span style="color: #0000ff">SVM</span>, CLASSIFIER_SUCCMETRIC: <span style="color: #ff0000">kappa_digitized_onlypos_2</span>, DATASET: <span style="color: #ff0000">siddata2022</span>, DCM_QUANT_MEASURE: <span style="color: #0000ff">count</span>, DEBUG: <span style="color: #ff0000">True</span>, DEBUG_N_ITEMS: <span style="color: #ff0000">500</span>, EMBED_ALGO: <span style="color: #0000ff">mds</span>, EMBED_DIMENSIONS: <span style="color: #ff0000">200</span>, EXTRACTION_METHOD: <span style="color: #ff0000">tfidf</span>, KAPPA_WEIGHTS: <span style="color: #0000ff">quadratic</span>, LANGUAGE: <span style="color: #0000ff">de</span>, MIN_WORDS_PER_DESC: <span style="color: #ff0000">80</span>, PP_COMPONENTS: <span style="color: #ff0000">mfauhcsd2</span>, PRIM_LAMBDA: <span style="color: #0000ff">0.5</span>, QUANTIFICATION_MEASURE: <span style="color: #ff0000">tfidf</span>, SEC_LAMBDA: <span style="color: #ff0000">0.2</span>, TRANSLATE_POLICY: <span style="color: #0000ff">onlyorig</span></span>

# %%
# %precision %.3f

def show_metrics(featureaxes, metric="kappa_rank2rank_onlypos_min", lamb1=0.5, lamb2=0.1):
    #I'm interested in:
    # *hat bin2bin/f_one ne hohe überschneidung mit anderen guten (kappa_rank2rank_onlypos_min, kappa_digitized_onlypos_2, kappa_count2rank_onlypos)
    # *was sind so die überschneidungen dieser guten 
    all_metrics = list(list(featureaxes["metrics"].values())[0].keys())
    print(all_metrics)
    one_metric = {k: v[metric] for k, v in featureaxes["metrics"].items()}
    one_metric = dict(sorted(one_metric.items(), reverse=True, key=lambda x : float('-inf') if np.isnan(x[1]) else x[1])) #https://stackoverflow.com/q/4240050/5122790
    t1 = {k: v for k, v in one_metric.items() if v >= lamb1}
    t2 = {k: v for k, v in one_metric.items() if v >= lamb2 and k not in t1.keys()}
    print(f"Lamb1: {lamb1} with {len(t1)} entries | Lamb2: {lamb2} with {len(t2)} entries | others: {len(one_metric)-len(t1)-len(t2)}")
    display(t1)
    print("="*50)
    display(t2)

def highlight_nonzero_max(data):
    #df.style.apply(highlight_nonzero_max, axis=0), https://stackoverflow.com/a/62639983/5122790
    #df.style.highlight_max(color='lightgreen', axis=0)
    return [f'font-weight: bold' if v == data.max() and v > 0 else '' for v in data]

def generate_comparertable(metrics, maxval=1.1, minval=0.5):
    all_metrics = list(list(metrics.values())[0].keys())
    t1_permetric = {}
    for metric in all_metrics:
        one_metric = {k: v[metric] for k, v in metrics.items()}
        one_metric = dict(sorted(one_metric.items(), reverse=True, key=lambda x : float('-inf') if np.isnan(x[1]) else x[1])) #https://stackoverflow.com/q/4240050/5122790
        t1 = {k: v for k, v in one_metric.items() if v >= minval and v < maxval}
        t1_permetric[metric] = set(t1.keys())
    t1_table = np.zeros([len(t1_permetric), len(t1_permetric)])
    for n1, k1 in enumerate(t1_permetric.values()):
        for n2, k2 in enumerate(t1_permetric.values()):
            t1_table[n1,n2] = len(k1&k2)/len(k1) if len(k1) > 0 else 0
    columns = [i.replace("kappa", "k").replace("dense", "d").replace("rank2rank", "r2r").replace("count2rank", "c2r").replace("bin2bin", "b2b").replace("f_one", "f1").replace("digitized", "dig").replace("_onlypos", "+") for i in t1_permetric.keys()]
    df = pd.DataFrame(t1_table, columns=columns, index=[f"{i} ({len(list(t1_permetric.values())[n])})" for n, i in enumerate(columns)])
    df.values[tuple([np.arange(df.shape[0])]*2)] = np.nan
    df = df.style.apply(highlight_nonzero_max, axis=1).format(precision=3)
    return df

# %%
show_metrics(featureaxes, lamb1=0.3, lamb2=0.05)
#I'm interested in:
# *hat bin2bin/f_one ne hohe überschneidung mit anderen guten (kappa_rank2rank_onlypos_min, kappa_digitized_onlypos_2, kappa_count2rank_onlypos)
# *was sind so die überschneidungen dieser guten
# Out:
# <span style="font-size:11pt">['accuracy', 'precision', 'recall', 'did_converge', 'f_one', 'kappa_rank2rank_dense', 'kappa_rank2rank_min', 'kappa_bin2bin', 'kappa_digitized', 'kappa_count2rank_onlypos', 'kappa_rank2rank_onlypos_dense', 'kappa_rank2rank_onlypos_min', 'kappa_rank2rank_onlypos_max', 'kappa_digitized_onlypos_2']</span>
# <span style="font-size:11pt">Lamb1: 0.3 with 470 entries | Lamb2: 0.05 with 4492 entries | others: 5098</span>
# {'uni bremen': 0.662,
#  'bremen de': 0.654,
#  'bremen': 0.645,
#  'betreuer': 0.628,
#  'uni bremen de': 0.627,
#  'mediation': 0.618,
#  'interkulturelles lernen': 0.608,
#  'haupt realschule': 0.597,
#  'schulpraktikum': 0.585,
#  'html': 0.583,
#  'the': 0.582,
#  'semesterhalfte': 0.580,
#  'pr uuml fung': 0.572,
#  'uhr raum 41': 0.572,
#  'lehrwerk': 0.563,
#  'ungefahr': 0.562,
#  'cher': 0.553,
#  'windows': 0.551,
#  'pro semester': 0.550,
#  'ubergreifende': 0.547,
#  'sterben': 0.546,
#  'artikulation': 0.544,
#  'tiere': 0.544,
#  'physischen geographie': 0.542,
#  'economics': 0.537,
#  'uuml fung': 0.534,
#  'of': 0.533,
#  'technische mechanik': 0.533,
#  'nbsp pr uuml': 0.526,
#  'teilnehmen mochten': 0.526,
#  'gelernten': 0.524,
#  'fung': 0.518,
#  'https': 0.518,
#  'geographen': 0.515,
#  'zusammen gestellt': 0.512,
#  'interkulturelles': 0.512,
#  'suffixe': 0.503,
#  'textsammlung': 0.502,
#  'migration': 0.501,
#  'tandem': 0.499,
#  'nbsp pr': 0.497,
#  'schulwesens': 0.495,
#  'and': 0.492,
#  'biophysik': 0.488,
#  'fink': 0.487,
#  'https www': 0.487,
#  'teilnahmevoraussetzungen veranstaltung richtet': 0.482,
#  'rucksprache': 0.481,
#  'vo': 0.480,
#  'abschnitte': 0.479,
#  'uni': 0.476,
#  'potentiellen': 0.470,
#  'menschenrechte': 0.470,
#  '06 2020': 0.468,
#  'rechtswissenschaft': 0.467,
#  'sollen teilnehmer': 0.466,
#  'stud ipad': 0.465,
#  'exemplarische inhalte': 0.464,
#  '30 uhr raum': 0.464,
#  'europ auml ischen': 0.463,
#  'tandempartnerschaften': 0.463,
#  'todes': 0.458,
#  'wissenschaftlichen arbeit': 0.458,
#  'regular': 0.454,
#  'course': 0.454,
#  'migrationsforschung': 0.449,
#  'pragmatik': 0.448,
#  'arabisch': 0.448,
#  'a1': 0.447,
#  'aufbauenden': 0.446,
#  'choice': 0.442,
#  'proben': 0.442,
#  'elementaren': 0.440,
#  'expose': 0.440,
#  'www': 0.439,
#  'studierende facher': 0.439,
#  'miteinander vergleichen': 0.439,
#  '00 uhr': 0.438,
#  'uhr': 0.436,
#  'geschickt': 0.435,
#  'niveau a2': 0.433,
#  'geographie bern': 0.432,
#  'studierende geographie bern': 0.432,
#  'arbeiten leitfaden studierende geographie bern': 0.432,
#  'leitfaden studierende geographie bern': 0.432,
#  '05 2020': 0.431,
#  '00uhr': 0.427,
#  'virtuos': 0.427,
#  'selbstrecherche': 0.426,
#  'interkulturalitat': 0.425,
#  'english': 0.425,
#  'www uni': 0.423,
#  'studierenden lernen': 0.423,
#  'niveau a1': 0.423,
#  'festlegung': 0.422,
#  'sprachlichen': 0.421,
#  'part': 0.421,
#  'emails': 0.420,
#  'ru': 0.418,
#  '19 uhr': 0.417,
#  'busch': 0.417,
#  'nbsp nbsp nbsp nbsp nbsp': 0.417,
#  'fakult auml ten': 0.417,
#  'sozialwiss': 0.416,
#  'niveau': 0.415,
#  'team': 0.414,
#  'mundliche schriftliche': 0.414,
#  'de': 0.414,
#  'barth': 0.413,
#  'hannover de': 0.412,
#  'sachunterricht': 0.412,
#  'architektur': 0.411,
#  'interkulturelle': 0.411,
#  'didaktik': 0.411,
#  'uni hannover': 0.411,
#  'a2': 0.410,
#  'htm': 0.409,
#  'schl uuml': 0.409,
#  'vorgesehen studierende': 0.409,
#  'tristan': 0.409,
#  '2021': 0.408,
#  'erwachsenenbildung': 0.408,
#  'gremien': 0.407,
#  'umfang ca': 0.406,
#  'leistungspunkte': 0.406,
#  'physische geographie': 0.406,
#  'auml glichen': 0.404,
#  'org 10': 0.403,
#  'ulmer stuttgart': 0.403,
#  '00': 0.403,
#  'gym': 0.400,
#  'schl': 0.400,
#  'bescheinigung': 0.399,
#  'schoningh': 0.398,
#  'unterrichtsforschung': 0.398,
#  'auml ischen': 0.398,
#  'mythos': 0.397,
#  'harvard': 0.397,
#  'of the': 0.397,
#  'fertigkeiten': 0.396,
#  'lessing': 0.396,
#  'rechte': 0.395,
#  'kunst': 0.392,
#  'bewohner': 0.391,
#  'nbsp nbsp': 0.391,
#  '14 tage': 0.390,
#  'umweltschutz': 0.390,
#  'recht': 0.389,
#  'ulmer': 0.389,
#  'teilgenommen': 0.389,
#  'konkreten ablauf': 0.388,
#  '2022': 0.388,
#  'anrechnung': 0.388,
#  'realschule': 0.388,
#  'interkulturellen': 0.387,
#  'ndiges': 0.386,
#  'kurse': 0.385,
#  'policy': 0.385,
#  'ethnologie': 0.385,
#  'romanistik europaische studien offen': 0.384,
#  'ischen': 0.384,
#  'nachweis': 0.383,
#  'fallstudie': 0.383,
#  'wochenende': 0.383,
#  'sozialstruktur': 0.382,
#  'auml che': 0.382,
#  'uni hannover de': 0.381,
#  'le': 0.380,
#  'europ auml': 0.380,
#  'schlusselkompetenzen': 0.379,
#  'str ouml': 0.378,
#  'herrn': 0.378,
#  'habermas': 0.376,
#  'besprechungen': 0.376,
#  'schulung': 0.375,
#  'language': 0.375,
#  'staatlicher': 0.375,
#  'governance': 0.372,
#  'konkreten ablauf veranstaltung': 0.372,
#  'fd': 0.371,
#  'radio': 0.370,
#  'to': 0.370,
#  'test': 0.370,
#  'ma studierende': 0.369,
#  'wissenschaftlichen arbeitens': 0.369,
#  'modul schl': 0.368,
#  'arbeitsteilung': 0.367,
#  'gerate': 0.367,
#  'auml cher': 0.367,
#  'sozialforschung': 0.366,
#  'modul schl uuml': 0.365,
#  'kreuz': 0.365,
#  'kette': 0.364,
#  'anfanger': 0.364,
#  'philosophie': 0.364,
#  'lerinnen sch uuml ler': 0.364,
#  'urheberrecht': 0.364,
#  '16 30 uhr': 0.364,
#  'ethik': 0.364,
#  'kunstunterricht': 0.364,
#  'teilnehmer_innen': 0.363,
#  'studierende fakult auml ten': 0.363,
#  'athen': 0.363,
#  '05': 0.361,
#  'veranstaltung studierenden': 0.361,
#  'studienrelevanten': 0.361,
#  'gesetze': 0.360,
#  'testverfahren': 0.360,
#  'veranstaltungen': 0.359,
#  'grundkurs': 0.359,
#  'tandemb': 0.359,
#  'tandemb uuml': 0.359,
#  'mathematik': 0.359,
#  'wunsche vorstellungen': 0.359,
#  'nbsp nbsp nbsp nbsp': 0.358,
#  'goethes': 0.358,
#  '15 15': 0.358,
#  'geographie behandelt': 0.358,
#  '11': 0.357,
#  'inhalt veranstaltung veranstaltung': 0.357,
#  'uuml lerinnen sch uuml ler': 0.357,
#  'fachdidaktik': 0.356,
#  '1972': 0.356,
#  'fahigkeit produktiven': 0.355,
#  'unternehmens': 0.355,
#  'through': 0.355,
#  'durchf uuml': 0.355,
#  '07 2020': 0.355,
#  'professionalisierungsbereich': 0.354,
#  'cher uuml': 0.354,
#  'auslandische': 0.354,
#  'europ': 0.353,
#  'bewerbung': 0.353,
#  'kognition': 0.353,
#  'sowie kenntnisse': 0.352,
#  'physischen geographie behandelt': 0.352,
#  'fahigkeit produktiven bereich systematische': 0.352,
#  'satzen': 0.352,
#  'list': 0.351,
#  'kunstler': 0.350,
#  'lernberatung': 0.350,
#  'gleichberechtigung': 0.350,
#  'blocks': 0.349,
#  'schwachen': 0.349,
#  'praktische beispiele': 0.349,
#  'produktiven': 0.348,
#  'schulpraktischen': 0.348,
#  'ki': 0.348,
#  'ausdrucke': 0.348,
#  'statten': 0.347,
#  'israel': 0.347,
#  'tage': 0.347,
#  '01': 0.347,
#  'gegeben literatur': 0.347,
#  'theoriebildung': 0.347,
#  'geschult': 0.346,
#  'schriftlich mundlich': 0.346,
#  'mittelschweren texten mundliche schriftliche kommunikative': 0.346,
#  'konrad': 0.346,
#  'ipad': 0.345,
#  'institution': 0.345,
#  'universitare': 0.344,
#  'deutsches europaisches': 0.344,
#  'stimme': 0.344,
#  'eu': 0.344,
#  'geschlechterforschung': 0.343,
#  'kommunikative fahigkeit produktiven bereich': 0.343,
#  'durchf': 0.343,
#  'grass': 0.343,
#  'doi org 10': 0.343,
#  'behandelt ziel': 0.343,
#  'vorbesprechungstermin': 0.342,
#  'sustainable': 0.342,
#  'forschungsseminar': 0.342,
#  'opladen': 0.342,
#  'mentor': 0.341,
#  'tutorium': 0.341,
#  'kunstlerinnen': 0.341,
#  'europaisches': 0.340,
#  'bereich lesefahigkeit': 0.339,
#  'mundliche schriftliche kommunikative fahigkeit produktiven': 0.339,
#  'straße': 0.339,
#  'anwendungsbereiche': 0.339,
#  'benachteiligte': 0.339,
#  'studierende fakult auml': 0.338,
#  'lesefahigkeit studienrelevanten spanischen mittelschweren texten': 0.338,
#  'lerninhalte': 0.338,
#  'weiss': 0.338,
#  'lehramt': 0.337,
#  'doi org': 0.337,
#  'webseite': 0.337,
#  'development': 0.337,
#  'versuche': 0.337,
#  'niveau b1': 0.337,
#  'synchron': 0.337,
#  'sch': 0.337,
#  'zoom': 0.336,
#  'ouml rderung': 0.336,
#  'kommunikative fahigkeit produktiven bereich systematische': 0.336,
#  'uberarb': 0.336,
#  'mittelschweren': 0.335,
#  'tools': 0.335,
#  'schuldrecht': 0.335,
#  'mittelschweren texten mundliche': 0.334,
#  'bielefeld transcript': 0.334,
#  'romanistik europaische': 0.334,
#  'romanistik europaische studien': 0.334,
#  'studierende fakult': 0.334,
#  'uuml': 0.334,
#  'einfuhrende lekture': 0.333,
#  'celan': 0.333,
#  'kurses rezeptiven bereich': 0.333,
#  'kurses rezeptiven bereich lesefahigkeit': 0.333,
#  'aktivierung studierenden themenorientierten': 0.333,
#  'kurses rezeptiven bereich lesefahigkeit studienrelevanten': 0.333,
#  'biologischen': 0.332,
#  '10': 0.331,
#  'methoden empirischen sozialforschung': 0.331,
#  'lesefahigkeit studienrelevanten': 0.331,
#  'konflikten': 0.330,
#  'kommentar beschreibung': 0.330,
#  'blended': 0.330,
#  'lineare': 0.330,
#  'juristen': 0.330,
#  'mundliche schriftliche kommunikative fahigkeit': 0.330,
#  'higkeit': 0.330,
#  'nbsp pr uuml fungsleistung': 0.330,
#  'beschaftigte': 0.330,
#  'tutorium beginnt': 0.330,
#  'bereich systematische aktivierung': 0.329,
#  'produktiven bereich': 0.329,
#  'bibliotheken': 0.329,
#  'nachhaltige': 0.329,
#  'lesefahigkeit studienrelevanten spanischen': 0.329,
#  'mundliche schriftliche kommunikative': 0.329,
#  'studip ab': 0.329,
#  'arbeitswelt': 0.329,
#  'mussen': 0.329,
#  '11 45': 0.329,
#  'interkulturelle kompetenz': 0.329,
#  'aktivierung studierenden themenorientierten hausaufgaben': 0.328,
#  'umgangsformen': 0.327,
#  'griechen': 0.327,
#  'hingewiesen': 0.327,
#  'vertraut dabei': 0.327,
#  'schließlich sollen': 0.327,
#  'bereich systematische': 0.326,
#  '04 2021': 0.326,
#  '20 00 uhr': 0.326,
#  'ev': 0.326,
#  'lesefahigkeit studienrelevanten spanischen mittelschweren': 0.326,
#  'kommunikative fahigkeit produktiven': 0.326,
#  'fahigkeit produktiven bereich systematische aktivierung': 0.326,
#  'sch uuml': 0.325,
#  'raum 41': 0.324,
#  'bereich lesefahigkeit studienrelevanten spanischen': 0.324,
#  'rderung': 0.324,
#  'produktiven bereich systematische aktivierung': 0.323,
#  'wolfram': 0.323,
#  'mittelschweren texten': 0.322,
#  'bereich systematische aktivierung studierenden': 0.322,
#  'bereich lesefahigkeit studienrelevanten': 0.322,
#  'auml ndiges': 0.322,
#  '16': 0.321,
#  'kurs': 0.321,
#  'b1': 0.321,
#  'gemeinsamkeiten unterschiede': 0.321,
#  'auml cher uuml': 0.321,
#  'exkursion': 0.320,
#  'islam': 0.320,
#  'europaische union': 0.320,
#  'physisch': 0.320,
#  'leistungsfahigkeit': 0.320,
#  'forderung': 0.320,
#  'vereinten nationen': 0.320,
#  'kursart': 0.319,
#  'pr': 0.319,
#  'kurses': 0.319,
#  'erhalten studierenden': 0.319,
#  'produktiven bereich systematische': 0.319,
#  'public': 0.319,
#  'klausuren': 0.318,
#  'auml higkeit': 0.318,
#  'per mail studip': 0.318,
#  'mittelschweren texten mundliche schriftliche': 0.318,
#  'alters': 0.318,
#  'fsz': 0.317,
#  'geographie': 0.317,
#  'je bedarf': 0.317,
#  'anrechenbar': 0.317,
#  'prufungen': 0.316,
#  'visuellen': 0.316,
#  'str': 0.316,
#  'theater': 0.315,
#  'bungen': 0.315,
#  'schule': 0.315,
#  'sk': 0.315,
#  'holz': 0.315,
#  'uuml bungen': 0.315,
#  'kurses rezeptiven': 0.315,
#  'workshop': 0.314,
#  'statistik': 0.314,
#  'standorte': 0.314,
#  'ects': 0.313,
#  'teilnahme ersten sitzung': 0.313,
#  'mail studip': 0.313,
#  'journalistische': 0.313,
#  '16 00 18': 0.313,
#  'vortrage': 0.313,
#  'europaischen referenzrahmens sprachen': 0.313,
#  'we': 0.313,
#  'kenntnisse fahigkeiten': 0.312,
#  'anrechnen': 0.312,
#  'kolloquium': 0.312,
#  'berufsbildenden schulen': 0.311,
#  'roms': 0.311,
#  'sports': 0.311,
#  '15': 0.311,
#  'fahigkeit produktiven bereich': 0.311,
#  'bereich lesefahigkeit studienrelevanten spanischen mittelschweren': 0.311,
#  'gemeinsamen europaischen referenzrahmens sprachen': 0.311,
#  'uhr raum': 0.311,
#  'vorlagen': 0.311,
#  'vereinten': 0.310,
#  'students': 0.310,
#  'nbsp voraussetzungen': 0.309,
#  'starken schwachen': 0.309,
#  'bereich systematische aktivierung studierenden themenorientierten': 0.309,
#  'ouml rungen': 0.309,
#  'unternehmen': 0.309,
#  'allgemeinsprachlichzielgruppe': 0.309,
#  'zusammenfassen': 0.309,
#  'lehr': 0.309,
#  'lp': 0.308,
#  'auml ten': 0.308,
#  'europaischen referenzrahmens': 0.308,
#  '01 10': 0.308,
#  'forschenden lernens': 0.308,
#  'bitte': 0.308,
#  'mogliche themen': 0.307,
#  'berufsbezogenen': 0.307,
#  'finanzierung': 0.307,
#  'lekture empfohlen': 0.307,
#  'hildesheim': 0.307,
#  'link http www': 0.307,
#  'ubersetzen': 0.307,
#  'entspannung': 0.307,
#  'allgemeiner': 0.307,
#  'auml': 0.306,
#  'fakult auml': 0.305,
#  'erweiterte auflage': 0.305,
#  '2021 22': 0.305,
#  'auml szlig': 0.305,
#  'hg': 0.304,
#  'stadtentwicklung': 0.304,
#  'inhalte vorlesung': 0.304,
#  'klima': 0.304,
#  'schriftzeichen': 0.303,
#  'quantitativen': 0.303,
#  'kunze': 0.302,
#  'alten testaments': 0.302,
#  'referenzrahmens sprachen': 0.302,
#  'doktoranden': 0.302,
#  'fakult': 0.302,
#  'aktivierung': 0.301,
#  'hrsg': 0.301,
#  'bachelor': 0.301,
#  'ten': 0.301,
#  'arbeitens': 0.300,
#  'bereich': 0.300}
# <span style="font-size:11pt">==================================================</span>
# {'12': 0.300,
#  'padagogik': 0.300,
#  'kompetent': 0.299,
#  'frankfurt suhrkamp': 0.299,
#  'publikation': 0.299,
#  'zusammenfassungen': 0.299,
#  'interkultureller': 0.299,
#  'fontane': 0.299,
#  'qualitative': 0.299,
#  '134': 0.298,
#  'vorlesung richtet studierende': 0.298,
#  '2019': 0.298,
#  'medien': 0.298,
#  'analog': 0.298,
#  'differenzierten': 0.297,
#  'teilgebiete': 0.297,
#  'erfolgreichen scheinerwerb': 0.297,
#  'bourdieu': 0.297,
#  'selbstmanagement': 0.296,
#  '07': 0.296,
#  'kirchen': 0.296,
#  'europaische': 0.296,
#  'forschungsthemen': 0.296,
#  'geistige': 0.296,
#  'subjekte': 0.295,
#  'auflage': 0.295,
#  '06': 0.295,
#  'verhandlung': 0.295,
#  'ber': 0.295,
#  'kritisch reflektieren': 0.294,
#  'anlehnung': 0.294,
#  'lesefahigkeit': 0.294,
#  'zusammengefasst': 0.294,
#  'prapositionen': 0.294,
#  'verona': 0.293,
#  'tier': 0.293,
#  'hannover': 0.293,
#  'grundschule': 0.292,
#  'praktischen uuml bungen': 0.292,
#  'forschungsmethoden': 0.291,
#  'briefe': 0.291,
#  'bgb': 0.291,
#  'university press': 0.291,
#  'theodor': 0.291,
#  'parteien': 0.290,
#  'atmosphare': 0.290,
#  'globalisierten': 0.290,
#  'usa': 0.290,
#  'griechische': 0.289,
#  'teilnahme aktive': 0.289,
#  'europaischen': 0.289,
#  'gemeinsamen europaischen referenzrahmens': 0.289,
#  'einf uuml': 0.288,
#  '14 18': 0.288,
#  'religionen': 0.288,
#  'variation': 0.288,
#  'technische': 0.288,
#  'ende kurses': 0.288,
#  'satz': 0.288,
#  'lerntagebuch': 0.287,
#  '16 00': 0.287,
#  'ouml': 0.287,
#  'gegenstand vorlesung': 0.287,
#  'seminarsitzungen': 0.287,
#  'einf': 0.287,
#  'ringvorlesung': 0.287,
#  'is': 0.286,
#  'verwiesen': 0.286,
#  'syntax': 0.286,
#  'resilienz': 0.286,
#  'us': 0.286,
#  'boden': 0.286,
#  'abend': 0.286,
#  'gegenstands': 0.286,
#  'mechanik': 0.286,
#  'van': 0.286,
#  'steuerrecht': 0.285,
#  'digitalisierung medien': 0.285,
#  'judentum': 0.284,
#  'europarecht': 0.284,
#  'geist': 0.284,
#  'uni osnabrueck de': 0.284,
#  'osnabruck': 0.284,
#  'teil veranstaltung': 0.284,
#  'erfolgt anlehnung': 0.284,
#  'for': 0.283,
#  'tagung': 0.283,
#  'verwaltungsrecht': 0.283,
#  'platon': 0.283,
#  'gesprachsfuhrung': 0.283,
#  'bescheinigt': 0.283,
#  'kunstgeschichte': 0.283,
#  'veranstaltung': 0.283,
#  'modul': 0.283,
#  'montag': 0.283,
#  'betrieblichen': 0.283,
#  '1961': 0.282,
#  'empirischen sozialforschung': 0.282,
#  'schreibwerkstatt': 0.282,
#  'erfolgreiche teilnahme': 0.282,
#  'forschungsprozess': 0.281,
#  'ws': 0.281,
#  '16 00 18 00': 0.281,
#  'beginnt': 0.281,
#  'la': 0.280,
#  'management': 0.280,
#  'geistlichen': 0.280,
#  'wiesbaden': 0.280,
#  'verfugbar': 0.280,
#  'data': 0.280,
#  'turn': 0.280,
#  'johann': 0.279,
#  'legitimation': 0.279,
#  'lv': 0.279,
#  'abstrakten': 0.279,
#  'uuml ber': 0.279,
#  'training': 0.279,
#  'frankfurt': 0.279,
#  'kulturwissenschaft': 0.279,
#  'wissenschaftstheorie': 0.279,
#  'stadt osnabruck': 0.279,
#  'besuchen': 0.278,
#  'rhetorische': 0.278,
#  'sessions': 0.278,
#  'zqs uni': 0.277,
#  'euro': 0.277,
#  'außerschulische': 0.277,
#  '45': 0.277,
#  'angekundigt': 0.277,
#  'forschenden': 0.277,
#  'smart': 0.277,
#  'paulus': 0.276,
#  'afrikanischen': 0.276,
#  'werbung': 0.276,
#  'statistische': 0.276,
#  'organisationen': 0.275,
#  'osnabrueck de': 0.275,
#  'geistiges': 0.275,
#  'sprachen': 0.275,
#  'anrechnen lassen': 0.275,
#  'managements': 0.275,
#  'wochentliche': 0.275,
#  'per mail': 0.274,
#  'gott': 0.274,
#  'wiesbaden springer': 0.274,
#  'studierende': 0.274,
#  'gegeben': 0.274,
#  'verwendeten': 0.274,
#  'folgendem': 0.274,
#  'stadt': 0.274,
#  'vorlesung': 0.273,
#  'dtv': 0.273,
#  'org': 0.273,
#  'ude': 0.273,
#  'seminars findet': 0.273,
#  'http': 0.273,
#  'ungleichheit': 0.273,
#  'zqs uni hannover de': 0.272,
#  'skript': 0.272,
#  'weitere entwicklung': 0.272,
#  'anzufertigen': 0.272,
#  'erz': 0.272,
#  'offentlicher': 0.272,
#  'lernen': 0.272,
#  'treffpunkt': 0.271,
#  'vorurteile': 0.271,
#  'europaische studien': 0.271,
#  '18': 0.270,
#  'lehrkr auml': 0.269,
#  'beginn veranstaltung bekannt': 0.269,
#  'zqs uni hannover': 0.269,
#  'ausgrenzung': 0.269,
#  'routledge': 0.269,
#  'dogmatik': 0.269,
#  'handlungskompetenz': 0.269,
#  'ubersetzt': 0.268,
#  'stadtgeographie': 0.268,
#  'stehen vordergrund': 0.268,
#  'mittelalter': 0.267,
#  'center': 0.267,
#  'argumentation': 0.267,
#  'projektmanagement': 0.267,
#  'klausur 90': 0.267,
#  'ca 100': 0.267,
#  'glichkeiten': 0.266,
#  'abgabe': 0.266,
#  'erz auml': 0.266,
#  '18 uhr': 0.266,
#  'ouml glichkeiten': 0.265,
#  'teilnahme referat': 0.265,
#  'haupt': 0.265,
#  'ehe': 0.265,
#  'forschen': 0.265,
#  'verankerung': 0.265,
#  'angeregt': 0.265,
#  'theologie': 0.265,
#  'literatur baade gertel schlottmann': 0.265,
#  'auml llen': 0.265,
#  'korpersprache': 0.265,
#  'gewasser': 0.264,
#  'online': 0.264,
#  '09 00': 0.264,
#  'buch': 0.264,
#  'ldquo': 0.264,
#  'http www': 0.264,
#  'norm': 0.264,
#  'horen': 0.264,
#  'digitalen': 0.264,
#  'qualifizierung': 0.264,
#  'film': 0.263,
#  'de anmeldung': 0.263,
#  'forschungsprozesses': 0.263,
#  'eltern': 0.263,
#  'menge': 0.263,
#  'english for': 0.263,
#  'historisches': 0.263,
#  'fr uuml': 0.262,
#  'ouml rper': 0.262,
#  'watch': 0.262,
#  'annahmen': 0.262,
#  'ausstellungen': 0.262,
#  'christus': 0.262,
#  'studiennachweise': 0.261,
#  'wiederholen': 0.261,
#  '2a': 0.261,
#  'studienbeginn': 0.261,
#  'marx': 0.261,
#  'literatur baade gertel': 0.261,
#  '16 18 uhr': 0.261,
#  'eschenbach': 0.260,
#  'be': 0.260,
#  'rper': 0.260,
#  'artefakte': 0.260,
#  'dienstag': 0.260,
#  'arbeitsmethoden': 0.260,
#  'qualifizierten': 0.260,
#  '10 2019': 0.260,
#  'roman': 0.260,
#  'museen': 0.259,
#  'stunde': 0.259,
#  'produktive mitarbeit': 0.259,
#  'schreiben': 0.259,
#  'jugend': 0.258,
#  'masterstudium': 0.258,
#  'kant': 0.258,
#  'orchester': 0.258,
#  'angebotenen': 0.258,
#  'uuml hrung': 0.258,
#  'anzupassen': 0.258,
#  'webinar': 0.257,
#  'beruflichen': 0.257,
#  'daten': 0.257,
#  'vertiefte kenntnisse': 0.257,
#  'soziale': 0.257,
#  'weiterbildung': 0.257,
#  'ankundigung': 0.257,
#  '16 00 uhr': 0.257,
#  'paderborn': 0.257,
#  'regionalentwicklung': 0.257,
#  'bibel': 0.257,
#  'lateinunterricht': 0.257,
#  'marketing': 0.257,
#  'min': 0.256,
#  'lsquo': 0.256,
#  'methoden': 0.256,
#  '30': 0.256,
#  'heimat': 0.256,
#  'sollen aktuelle': 0.256,
#  'uuml ler innen': 0.255,
#  'teilnahmevoraussetzungen veranstaltung': 0.255,
#  'ch': 0.255,
#  'com': 0.255,
#  'analysis': 0.255,
#  'ziel kurses': 0.255,
#  'romanistik': 0.255,
#  'tats auml chlich': 0.255,
#  'ordner': 0.254,
#  'benjamin': 0.254,
#  'virtuellen': 0.254,
#  'blended learning': 0.254,
#  'nbsp studierende': 0.254,
#  'hermeneutik': 0.254,
#  'internationalisierung': 0.254,
#  'begleitseminar': 0.254,
#  'diagnostische': 0.254,
#  'sa': 0.254,
#  'vergleichenden': 0.254,
#  'aufgefuhrt': 0.253,
#  'technik': 0.253,
#  'bildungswesen': 0.253,
#  'participants': 0.253,
#  'oktober': 0.253,
#  'einf uuml hrung': 0.253,
#  'https www youtube': 0.253,
#  'ro': 0.253,
#  'schillers': 0.252,
#  'melden uuml': 0.252,
#  'bitte melden uuml': 0.252,
#  'rungen': 0.252,
#  'anlehnung niveau': 0.252,
#  'gemeinsamen': 0.252,
#  'powerpoint': 0.252,
#  'februar': 0.252,
#  'vorbereitung fachpraktikum': 0.252,
#  'offentliches recht': 0.251,
#  'entspannungstechniken': 0.251,
#  'bergreifender bachelor': 0.251,
#  'hartmut': 0.251,
#  'url': 0.251,
#  'uuml bergreifender bachelor': 0.251,
#  'eva': 0.251,
#  'ende zweiten': 0.251,
#  'design': 0.250,
#  'facher bachelor': 0.250,
#  'weimarer republik': 0.250,
#  'sitzung': 0.250,
#  '1918': 0.250,
#  'veranstaltung vorlesung': 0.250,
#  'bergreifender': 0.250,
#  'not': 0.250,
#  'emotionalen': 0.250,
#  'kirche': 0.249,
#  'chr': 0.249,
#  'praxisphase': 0.249,
#  'pisa': 0.249,
#  'museum': 0.249,
#  'kindern': 0.249,
#  'facher': 0.249,
#  'interviews': 0.249,
#  'gesundheitsforderung': 0.249,
#  'kohlhammer': 0.249,
#  'renaissance': 0.249,
#  'islamische': 0.249,
#  'cher uuml bergreifender bachelor': 0.249,
#  'erfolgreiche': 0.249,
#  'mode': 0.249,
#  'musikunterricht': 0.248,
#  'sicherung': 0.248,
#  'humangeographie': 0.248,
#  'forum': 0.248,
#  'erklarungsansatze': 0.248,
#  'april 2020': 0.248,
#  '46': 0.248,
#  'testament': 0.248,
#  'auflage munchen': 0.248,
#  'bildung': 0.248,
#  'allgemeinen': 0.248,
#  'akteure': 0.248,
#  'law': 0.248,
#  'tragodie': 0.247,
#  'interaktiven': 0.247,
#  'wichtiger hinweis': 0.247,
#  'verhaltensweisen': 0.247,
#  'lehrerinnen': 0.246,
#  'ikc': 0.246,
#  'soziologischen': 0.246,
#  'erwerb': 0.246,
#  'springer': 0.246,
#  'eigenst': 0.246,
#  'sws': 0.246,
#  'nachhaltige entwicklung': 0.245,
#  'arbeiten': 0.245,
#  'hrung': 0.245,
#  'studium': 0.245,
#  'uuml bergreifender': 0.245,
#  '15 seiten': 0.245,
#  '49': 0.245,
#  '01 10 2019 bereich': 0.245,
#  'on': 0.245,
#  '10 2019 bereich': 0.245,
#  'berechtigt': 0.245,
#  'quantitativer': 0.245,
#  'eigenst auml': 0.244,
#  '2019 bereich': 0.244,
#  'schwerpunktbereichs': 0.244,
#  'ab': 0.244,
#  'konstruktivismus': 0.244,
#  'university': 0.244,
#  'neuzeit': 0.244,
#  'globalen': 0.244,
#  'mathematische': 0.244,
#  'konto': 0.243,
#  'verschiedenen methoden': 0.243,
#  'veranstaltung richtet studierende': 0.243,
#  'geographisch': 0.243,
#  'funften': 0.243,
#  'gelernte': 0.243,
#  'digitale': 0.242,
#  'musik': 0.242,
#  'niedersachsen': 0.242,
#  'bachelor studiengang': 0.242,
#  'auml ude': 0.242,
#  'qualitative sozialforschung': 0.241,
#  '10 00 12': 0.241,
#  'ab 01': 0.241,
#  'donnerstag': 0.241,
#  'nachhaltigkeit': 0.241,
#  'abgegeben': 0.241,
#  'masterstudiengangs': 0.241,
#  'losung': 0.241,
#  'profil': 0.241,
#  'messen': 0.241,
#  'einordnung': 0.241,
#  '20 studierende': 0.241,
#  'vorstellungsgesprach': 0.240,
#  'lateinamerika': 0.240,
#  'ndige': 0.240,
#  'kleingruppe': 0.240,
#  'malerei': 0.240,
#  'arbeitsaufgabe': 0.240,
#  'forschungsansatze': 0.240,
#  'as': 0.239,
#  'course is': 0.239,
#  'verhaltens': 0.239,
#  'soziologie': 0.239,
#  'personlichkeitsentwicklung': 0.239,
#  'bestandteile': 0.239,
#  'geb': 0.239,
#  'uuml studierende': 0.238,
#  'christologie': 0.238,
#  'gabriel': 0.238,
#  'stufe': 0.238,
#  'bdquo': 0.238,
#  'christlichen glaubens': 0.238,
#  'tests': 0.237,
#  'pravention': 0.237,
#  'passen': 0.237,
#  'ge': 0.237,
#  'praktischen uuml': 0.237,
#  'erlernte': 0.237,
#  'erfolgt anlehnung niveau': 0.237,
#  'studierenden': 0.237,
#  'gesundheit': 0.237,
#  'auschwitz': 0.237,
#  'kompetenzen': 0.236,
#  'teilnahme ersten': 0.236,
#  'uuml online': 0.236,
#  'syntax semantik': 0.236,
#  'mobilitat': 0.236,
#  'tablet': 0.236,
#  'originalen': 0.236,
#  'prasentation': 0.236,
#  'auslandsstudium': 0.236,
#  'lateinischen': 0.236,
#  'gemeinsamen europaischen': 0.235,
#  'naturliche': 0.235,
#  'nbsp nbsp nbsp': 0.235,
#  'kcl': 0.235,
#  'unterrichtsstunden': 0.235,
#  'ankunft': 0.235,
#  'career': 0.235,
#  'are': 0.235,
#  'politiken': 0.235,
#  '31': 0.235,
#  'strukturierte': 0.235,
#  'gef': 0.234,
#  '14': 0.234,
#  'findet online uuml': 0.234,
#  'mitglieder': 0.234,
#  'korper': 0.234,
#  'erarbeitet diskutiert': 0.234,
#  'zunehmender': 0.234,
#  'auml ndige': 0.234,
#  'teilbereich': 0.234,
#  'deutschlands': 0.234,
#  'introduction': 0.234,
#  'budrich': 0.234,
#  'menschen': 0.234,
#  'umwelt': 0.234,
#  'fotografie': 0.234,
#  'englischsprachigen': 0.233,
#  'universitat': 0.233,
#  'gerne': 0.233,
#  'souveran': 0.233,
#  'uni osnabrueck': 0.233,
#  'per': 0.232,
#  'einfuhrung': 0.232,
#  'fachbereichs': 0.232,
#  'seminarteilnehmerinnen': 0.232,
#  'with': 0.232,
#  'gleichzeitige': 0.232,
#  'vernunft': 0.232,
#  'imis': 0.231,
#  'sozialgeographie': 0.231,
#  'fachrichtung': 0.231,
#  'empirischen': 0.231,
#  'ausgedruckt': 0.231,
#  'dr': 0.231,
#  '00 13': 0.231,
#  'anschließenden': 0.231,
#  'unterrichtsformen': 0.231,
#  'auml cher uuml bergreifender bachelor': 0.231,
#  'link': 0.231,
#  'fallstudien': 0.230,
#  'verlag': 0.230,
#  '20 10': 0.230,
#  '02': 0.230,
#  'indien': 0.230,
#  'erhebungen': 0.229,
#  'termin': 0.229,
#  'fn': 0.229,
#  'manner': 0.229,
#  'rhetorik': 0.229,
#  'evangelischen': 0.229,
#  'erinnerungskultur': 0.229,
#  'politics': 0.229,
#  'mitarbeiter innen': 0.229,
#  'sommersemester': 0.229,
#  'wissenschaftlicher': 0.229,
#  'gewahrleistet': 0.228,
#  'cher uuml bergreifender': 0.228,
#  'youtube com': 0.228,
#  'erforderliche': 0.228,
#  'auml cher uuml bergreifender': 0.228,
#  'semester sowie': 0.228,
#  '12 15 seiten': 0.228,
#  'erworbenen kenntnisse': 0.227,
#  'solide': 0.227,
#  'mundlicher': 0.227,
#  '01 10 2019': 0.227,
#  'einfuhrung wissenschaftliche': 0.226,
#  'erscheinungen': 0.226,
#  'referentin': 0.226,
#  'vollst auml': 0.226,
#  'kommilitonen': 0.226,
#  'museums': 0.226,
#  'qualitativer': 0.225,
#  'ects punkte': 0.225,
#  'einzelnen seminarsitzungen': 0.225,
#  'bewerben': 0.225,
#  'germanistische': 0.225,
#  'protokoll': 0.225,
#  'krieg': 0.225,
#  'kurse erfolgt': 0.225,
#  'business': 0.225,
#  'zeugnisse': 0.225,
#  'freitag': 0.225,
#  'friedrich': 0.225,
#  'bus': 0.225,
#  'erstellen': 0.225,
#  'psychischen krise befinden': 0.225,
#  'dialoge': 0.225,
#  'handouts': 0.225,
#  'kunstler innen': 0.224,
#  'personal': 0.224,
#  'oldenbourg': 0.224,
#  'prufung': 0.224,
#  'cultural': 0.224,
#  'integriert': 0.224,
#  'teil': 0.224,
#  'begleitveranstaltung': 0.223,
#  'schriftliche ausarbeitung': 0.223,
#  'parallelen': 0.223,
#  'lehrkr': 0.223,
#  'on the': 0.223,
#  'sprachwissenschaft': 0.223,
#  'einfuhrung methoden': 0.223,
#  'heterogenitat': 0.223,
#  'france': 0.223,
#  'systemischen': 0.223,
#  'vorgesetzten': 0.223,
#  'kompakt': 0.222,
#  'alten': 0.222,
#  'bachelorstudiengang': 0.222,
#  'januar': 0.222,
#  'https www youtube com': 0.222,
#  'konkretes': 0.222,
#  'auftritt': 0.222,
#  'verhalten': 0.222,
#  'labor': 0.222,
#  'utb': 0.222,
#  'di': 0.222,
#  'bitte stud': 0.221,
#  'verschiedene aspekte': 0.221,
#  'link http': 0.221,
#  'lernwerkstatt': 0.221,
#  'rational': 0.221,
#  'lehrers': 0.221,
#  'menschliches': 0.221,
#  'unterrichtspraxis': 0.221,
#  '04': 0.221,
#  'vorlesung richtet': 0.221,
#  'mails': 0.221,
#  'mo': 0.221,
#  'juristische': 0.220,
#  'frankfurt main': 0.220,
#  'prasenzlehre': 0.220,
#  'glaubens': 0.220,
#  'detaillierte': 0.220,
#  'rollenspiel': 0.220,
#  'utopien': 0.220,
#  'the course': 0.220,
#  '90 min': 0.220,
#  '1969': 0.220,
#  'frauen': 0.220,
#  'medizin': 0.220,
#  'wissenschaftlichen': 0.219,
#  'zugehorigen': 0.219,
#  'veranstaltung veranstaltung': 0.219,
#  'vollst auml ndige': 0.219,
#  'systematische': 0.219,
#  'karin': 0.219,
#  'www youtube com': 0.219,
#  'exemplarische': 0.218,
#  'erhalten rechtzeitig': 0.218,
#  '16 30': 0.218,
#  'tats auml': 0.218,
#  'tats': 0.218,
#  '12 14 uhr': 0.218,
#  'cambridge': 0.218,
#  'semantik': 0.218,
#  'https www youtube com watch': 0.218,
#  'auseinandersetzung ausgewahlten': 0.218,
#  'sem': 0.218,
#  'stabile': 0.218,
#  'fachsprache': 0.218,
#  'kinder': 0.218,
#  'texte verfassen': 0.218,
#  'zielgruppe': 0.218,
#  '00 12': 0.218,
#  'schwerpunkt': 0.217,
#  'kurz beginn': 0.217,
#  'dialog': 0.217,
#  'pr uuml': 0.217,
#  'bauern': 0.217,
#  'wiederholung': 0.217,
#  'studiengange': 0.217,
#  'emanzipation': 0.217,
#  'themenorientierten': 0.217,
#  'studiengang': 0.216,
#  'bundesrepublik': 0.216,
#  'herz': 0.216,
#  'literaturunterricht': 0.216,
#  'forschungsprojekten': 0.216,
#  'ler innen': 0.216,
#  'leitet': 0.216,
#  'burger': 0.215,
#  'wahrzunehmen': 0.215,
#  'erich': 0.215,
#  '28 10': 0.215,
#  'fsz uni': 0.215,
#  '32': 0.215,
#  'demgegenuber': 0.215,
#  'rechts': 0.214,
#  'vorlesungen': 0.214,
#  '12 00': 0.214,
#  'www youtube': 0.214,
#  'handbook': 0.214,
#  'befragungen': 0.214,
#  'blockseminar': 0.214,
#  'kurs vorgesehen': 0.214,
#  'partien': 0.214,
#  'online verfugbar': 0.214,
#  'erscheinungsformen': 0.214,
#  'republik': 0.213,
#  'unterrichtsvorbereitung': 0.213,
#  'fragestellungen methoden': 0.213,
#  'innovative': 0.213,
#  'anwesenheitspflicht': 0.213,
#  'rezeptiven': 0.213,
#  'mail': 0.213,
#  'fr uuml hen': 0.213,
#  'beruflichen bildung': 0.213,
#  'franz ouml': 0.213,
#  'erl auml': 0.212,
#  'union': 0.212,
#  'nord': 0.212,
#  'krise befinden': 0.212,
#  'psychischen krise': 0.212,
#  'erledigung': 0.212,
#  'zielgruppe studierende': 0.212,
#  'unterschiede': 0.212,
#  'gesundheitlichen': 0.212,
#  'zeichnen': 0.212,
#  'aktivierung studierenden': 0.212,
#  'behandelt': 0.212,
#  '14 uhr': 0.212,
#  'fuhrungen': 0.212,
#  'blocken': 0.212,
#  'kulturen': 0.211,
#  'chemische': 0.211,
#  'bung': 0.211,
#  'objektiven': 0.211,
#  'strukturierten': 0.211,
#  'bewahrt': 0.211,
#  '17': 0.211,
#  'flucht': 0.211,
#  'padagogischen': 0.211,
#  'university of': 0.211,
#  'methoden inhalte': 0.211,
#  'staats': 0.211,
#  'prozesse': 0.211,
#  'lernprozessen': 0.211,
#  'projekt': 0.211,
#  'klinkhardt': 0.211,
#  'praxisbeispielen': 0.210,
#  'workshop findet': 0.210,
#  'alltagssituationen': 0.210,
#  'aufl': 0.210,
#  'grundrechte': 0.210,
#  'entsprechenden tutorien': 0.210,
#  'folgende themen': 0.210,
#  'fremd': 0.210,
#  'meistern': 0.210,
#  'master': 0.210,
#  'che': 0.209,
#  'vier': 0.209,
#  'bewegungen': 0.209,
#  'uwe': 0.209,
#  'szlig': 0.209,
#  'bertolt': 0.209,
#  '15 jahrhundert': 0.209,
#  'bed': 0.209,
#  'press': 0.209,
#  'veranstaltung richtet': 0.209,
#  '1b': 0.209,
#  'beeintr': 0.208,
#  'elisabeth': 0.208,
#  'ew': 0.208,
#  'corona krise': 0.208,
#  'vs verlag': 0.208,
#  'sozialer': 0.208,
#  '1800': 0.208,
#  'munchen': 0.208,
#  'richtet studierende': 0.208,
#  'durchgef uuml': 0.207,
#  'emotionen': 0.207,
#  'inhalten': 0.207,
#  'sowie aktive': 0.207,
#  'uuml hen': 0.207,
#  '2020': 0.207,
#  'statt': 0.207,
#  'osnabrueck': 0.206,
#  'beruflicher': 0.206,
#  'losungsvorschlage': 0.206,
#  'office': 0.206,
#  'themen': 0.206,
#  'geschichte': 0.206,
#  'auml rt': 0.206,
#  'konfessionell': 0.206,
#  'studip': 0.206,
#  'erde': 0.206,
#  'nationen': 0.206,
#  'april': 0.206,
#  'grundzuge': 0.206,
#  'personliches': 0.205,
#  'durchf uuml hrung': 0.205,
#  'planen': 0.205,
#  'berg': 0.205,
#  'mitarbeiter': 0.205,
#  'kunste': 0.205,
#  '00 uhr raum': 0.205,
#  'osten': 0.205,
#  'serie': 0.205,
#  'mittelhochdeutsche': 0.205,
#  'studierende bachelor': 0.205,
#  'el': 0.205,
#  'uuml lerinnen sch': 0.205,
#  'konflikte': 0.205,
#  'literaturwissenschaft': 0.204,
#  'produzieren': 0.204,
#  'wendet studierende': 0.204,
#  'gef uuml': 0.204,
#  'afrika': 0.204,
#  'seminar grundlagen': 0.204,
#  'forschungswerkstatt': 0.204,
#  'schreib': 0.204,
#  'lorenz': 0.204,
#  'chicago': 0.204,
#  '1989': 0.204,
#  'psychologischer': 0.204,
#  'studierenden erwerben': 0.204,
#  'albrecht': 0.204,
#  'what': 0.204,
#  'fsz uni hannover': 0.203,
#  'netzwerken': 0.203,
#  'umfang': 0.203,
#  'momente': 0.203,
#  'wahr': 0.203,
#  'verfolgung': 0.203,
#  'nnen': 0.203,
#  'verbuchung': 0.203,
#  'block': 0.203,
#  'city': 0.203,
#  '09': 0.203,
#  'hauptstudium': 0.202,
#  'englisch': 0.202,
#  'ouml nnen': 0.202,
#  'nacht': 0.202,
#  'kuhl': 0.202,
#  'uos': 0.202,
#  'katholischen kirche': 0.202,
#  'auftretenden': 0.202,
#  'sicherer': 0.202,
#  '2020 14': 0.202,
#  'bew auml ltigung': 0.201,
#  'semester': 0.201,
#  'recherchieren': 0.201,
#  'peters': 0.201,
#  'modernen gesellschaft': 0.201,
#  'anwendung': 0.201,
#  'innen': 0.201,
#  'reflexive': 0.201,
#  'geb auml ude': 0.201,
#  'religion': 0.201,
#  'inhalt vorlesung': 0.201,
#  'sozialen': 0.200,
#  'wachstum': 0.200,
#  'zusammenfassung': 0.200,
#  'gemeinde': 0.200,
#  'wirtschaftlicher': 0.200,
#  'kenntnisse': 0.200,
#  'tigkeit': 0.200,
#  'paul': 0.200,
#  'erinnern': 0.200,
#  'dienste': 0.200,
#  'individuum': 0.200,
#  'wetter': 0.200,
#  'illustriert': 0.200,
#  'beim schreiben': 0.199,
#  'regieren': 0.199,
#  'studienleistungen': 0.199,
#  'teilnehmen': 0.199,
#  'benotung': 0.199,
#  'zielgruppe studierende fakult': 0.199,
#  'gegenseitigen': 0.199,
#  'unsicher': 0.199,
#  'hof': 0.199,
#  'teilnahme': 0.199,
#  'statt weitere': 0.199,
#  '978 12': 0.199,
#  'informellen': 0.199,
#  'fachsemester': 0.198,
#  'digitalisierung': 0.198,
#  'raum': 0.198,
#  'journalismus': 0.198,
#  'annahme': 0.198,
#  'pr auml': 0.198,
#  'japanische': 0.198,
#  'classroom': 0.198,
#  'bundesrepublik deutschland': 0.198,
#  'begleitenden': 0.198,
#  'ausland': 0.198,
#  '13 30 uhr': 0.198,
#  'kindheit': 0.198,
#  'stress': 0.198,
#  'kunstlerische': 0.198,
#  'efp': 0.198,
#  '15 00 uhr': 0.198,
#  'ubersetzungen': 0.198,
#  'kurs vorgesehen studierende': 0.197,
#  'ii': 0.197,
#  'methoden empirischen': 0.197,
#  'schulen': 0.197,
#  'internationales': 0.197,
#  'naturwissenschaftlichen': 0.197,
#  'baden': 0.197,
#  'entdecken': 0.197,
#  'nachbereitung': 0.197,
#  'kultur': 0.197,
#  'inhalt veranstaltung': 0.197,
#  'balance': 0.197,
#  'lieder': 0.197,
#  'durchgef': 0.197,
#  'sozialwiss uni': 0.197,
#  'deutsch': 0.197,
#  'entdeckung': 0.197,
#  'moderne': 0.197,
#  'main': 0.196,
#  'militarische': 0.196,
#  'inklusiver': 0.196,
#  'studenten': 0.196,
#  'zweiten weltkrieg': 0.196,
#  '13': 0.196,
#  'jakob': 0.196,
#  'vorheriger': 0.196,
#  'chancen': 0.196,
#  'fr': 0.196,
#  'zielgruppe studierende fakult auml': 0.196,
#  'rechtfertigung': 0.196,
#  'judith': 0.196,
#  'seiten': 0.195,
#  'erinnerung': 0.195,
#  'pflanzen': 0.195,
#  'oberstufe': 0.195,
#  'ba ma': 0.195,
#  'fuhrung': 0.195,
#  'teilnahmevoraussetzungen': 0.195,
#  'grundlagenwissen': 0.195,
#  'seminare': 0.195,
#  'regelm auml szlig': 0.195,
#  'komponisten': 0.195,
#  'beeintr auml': 0.195,
#  'richtlinien': 0.195,
#  'verstehen': 0.194,
#  'option': 0.194,
#  'horn': 0.194,
#  'art weise': 0.194,
#  'maßnahmen': 0.194,
#  'de la': 0.194,
#  'textanalyse': 0.193,
#  'verfugen': 0.193,
#  'wissenschaftlichen texten': 0.193,
#  'materie': 0.193,
#  'schonen': 0.193,
#  'zuordnung': 0.193,
#  'praktikum': 0.193,
#  'einuben': 0.193,
#  '10 00 uhr': 0.193,
#  'einschließlich': 0.193,
#  'www uni osnabrueck de': 0.193,
#  'richtet': 0.193,
#  'angegebenen': 0.193,
#  'reflexion': 0.192,
#  'studentinnen studenten': 0.192,
#  'literaturwissenschaftliche': 0.192,
#  'fn adl': 0.192,
#  'charakterisierung': 0.192,
#  'luther': 0.192,
#  'zlb': 0.192,
#  'heinz': 0.192,
#  'bereits beginn': 0.192,
#  'your': 0.192,
#  'uuml bingen': 0.192,
#  'beruflicher bildung': 0.192,
#  'gesellschaft': 0.192,
#  '04 2020': 0.192,
#  'llen': 0.192,
#  'vollst': 0.192,
#  'anmeldungen': 0.191,
#  'wirtschaftspolitik': 0.191,
#  'informatik': 0.191,
#  'festgelegten': 0.191,
#  'organisations': 0.191,
#  'nationalsozialismus': 0.191,
#  'arbeits': 0.191,
#  'soziale ungleichheit': 0.191,
#  'ag': 0.191,
#  'aussprache': 0.191,
#  'angeboten': 0.191,
#  'romischen': 0.190,
#  'beck': 0.190,
#  'stereotype': 0.190,
#  'literaturempfehlungen': 0.190,
#  'glauben': 0.190,
#  'aufgrund aktuellen': 0.190,
#  '11 2020': 0.190,
#  'humanismus': 0.190,
#  'gehalt': 0.190,
#  'bachelor master': 0.190,
#  'abschlussarbeit': 0.190,
#  'fahigkeiten': 0.190,
#  'bspw': 0.190,
#  'erlautern': 0.190,
#  'mitarbeiten': 0.190,
#  'herbert': 0.190,
#  'brd': 0.190,
#  'ansatze': 0.189,
#  'romans': 0.189,
#  'jesu': 0.189,
#  'amerikanischen': 0.189,
#  'blockveranstaltung': 0.189,
#  'entscheidungsprozesse': 0.189,
#  'ndl': 0.189,
#  'freundschaft': 0.189,
#  'chinesischen': 0.189,
#  'planung': 0.189,
#  '117': 0.189,
#  'strafrecht': 0.188,
#  'islamischen': 0.188,
#  'selbstprasentation': 0.188,
#  'religionsunterricht': 0.188,
#  'grundriss': 0.188,
#  'isbn 978 12': 0.188,
#  'verortung': 0.188,
#  'padagogische': 0.188,
#  'amp': 0.188,
#  'praktischer': 0.188,
#  'un': 0.188,
#  'rechner': 0.188,
#  'kompetenz': 0.188,
#  'entwicklung eigenen': 0.188,
#  'diversity': 0.188,
#  '00 16 00 uhr': 0.188,
#  'studentin': 0.187,
#  'ablaufe': 0.187,
#  'semesters': 0.187,
#  'masterarbeiten': 0.187,
#  'suche': 0.187,
#  'sch uuml ler innen': 0.187,
#  'ruckfragen': 0.187,
#  'fernsehen': 0.187,
#  'general': 0.187,
#  'erg auml nzend': 0.187,
#  'auml nzend': 0.187,
#  'lateinischer': 0.187,
#  'vermeidung': 0.187,
#  'gesprachen': 0.187,
#  'normalen': 0.187,
#  'alltaglichen': 0.187,
#  ...}

# %%
generate_comparertable(sample_ctx.obj["featureaxes"]["metrics"], minval=0.5)
#look at combis of bin2bin, f_one, k_r2r+_min, k_dig+_2, k_c2r+
# Out:
# <style type="text/css">
# #T_4b0bf_row0_col2, #T_4b0bf_row1_col0, #T_4b0bf_row1_col2, #T_4b0bf_row1_col4, #T_4b0bf_row2_col0, #T_4b0bf_row3_col0, #T_4b0bf_row3_col2, #T_4b0bf_row4_col0, #T_4b0bf_row4_col2, #T_4b0bf_row7_col0, #T_4b0bf_row7_col2, #T_4b0bf_row7_col4, #T_4b0bf_row11_col0, #T_4b0bf_row11_col2, #T_4b0bf_row12_col0, #T_4b0bf_row12_col2, #T_4b0bf_row13_col0, #T_4b0bf_row13_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4b0bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b0bf_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_4b0bf_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_4b0bf_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_4b0bf_level0_col3" class="col_heading level0 col3" >did_converge</th>
#       <th id="T_4b0bf_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_4b0bf_level0_col5" class="col_heading level0 col5" >k_r2r_d</th>
#       <th id="T_4b0bf_level0_col6" class="col_heading level0 col6" >k_r2r_min</th>
#       <th id="T_4b0bf_level0_col7" class="col_heading level0 col7" >k_b2b</th>
#       <th id="T_4b0bf_level0_col8" class="col_heading level0 col8" >k_dig</th>
#       <th id="T_4b0bf_level0_col9" class="col_heading level0 col9" >k_c2r+</th>
#       <th id="T_4b0bf_level0_col10" class="col_heading level0 col10" >k_r2r+_d</th>
#       <th id="T_4b0bf_level0_col11" class="col_heading level0 col11" >k_r2r+_min</th>
#       <th id="T_4b0bf_level0_col12" class="col_heading level0 col12" >k_r2r+_max</th>
#       <th id="T_4b0bf_level0_col13" class="col_heading level0 col13" >k_dig+_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b0bf_level0_row0" class="row_heading level0 row0" >accuracy (10060)</th>
#       <td id="T_4b0bf_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_4b0bf_row0_col1" class="data row0 col1" >0.082</td>
#       <td id="T_4b0bf_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_4b0bf_row0_col3" class="data row0 col3" >0.882</td>
#       <td id="T_4b0bf_row0_col4" class="data row0 col4" >0.122</td>
#       <td id="T_4b0bf_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_4b0bf_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_4b0bf_row0_col7" class="data row0 col7" >0.118</td>
#       <td id="T_4b0bf_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_4b0bf_row0_col9" class="data row0 col9" >0.000</td>
#       <td id="T_4b0bf_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_4b0bf_row0_col11" class="data row0 col11" >0.004</td>
#       <td id="T_4b0bf_row0_col12" class="data row0 col12" >0.002</td>
#       <td id="T_4b0bf_row0_col13" class="data row0 col13" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_4b0bf_level0_row1" class="row_heading level0 row1" >precision (828)</th>
#       <td id="T_4b0bf_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_4b0bf_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_4b0bf_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_4b0bf_row1_col3" class="data row1 col3" >0.986</td>
#       <td id="T_4b0bf_row1_col4" class="data row1 col4" >1.000</td>
#       <td id="T_4b0bf_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_4b0bf_row1_col6" class="data row1 col6" >0.000</td>
#       <td id="T_4b0bf_row1_col7" class="data row1 col7" >0.998</td>
#       <td id="T_4b0bf_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_4b0bf_row1_col9" class="data row1 col9" >0.000</td>
#       <td id="T_4b0bf_row1_col10" class="data row1 col10" >0.000</td>
#       <td id="T_4b0bf_row1_col11" class="data row1 col11" >0.005</td>
#       <td id="T_4b0bf_row1_col12" class="data row1 col12" >0.002</td>
#       <td id="T_4b0bf_row1_col13" class="data row1 col13" >0.068</td>
#     </tr>
#     <tr>
#       <th id="T_4b0bf_level0_row2" class="row_heading level0 row2" >recall (10060)</th>
#       <td id="T_4b0bf_row2_col0" class="data row2 col0" >1.000</td>
#       <td id="T_4b0bf_row2_col1" class="data row2 col1" >0.082</td>
#       <td id="T_4b0bf_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_4b0bf_row2_col3" class="data row2 col3" >0.882</td>
#       <td id="T_4b0bf_row2_col4" class="data row2 col4" >0.122</td>
#       <td id="T_4b0bf_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_4b0bf_row2_col6" class="data row2 col6" >0.000</td>
#       <td id="T_4b0bf_row2_col7" class="data row2 col7" >0.118</td>
#       <td id="T_4b0bf_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_4b0bf_row2_col9" class="data row2 col9" >0.000</td>
#       <td id="T_4b0bf_row2_col10" class="data row2 col10" >0.000</td>
#       <td id="T_4b0bf_row2_col11" class="data row2 col11" >0.004</td>
#       <td id="T_4b0bf_row2_col12" class="data row2 col12" >0.002</td>
#       <td id="T_4b0bf_row2_col13" class="data row2 col13" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_4b0bf_level0_row3" class="row_heading level0 row3" >did_converge (8876)</th>
#       <td id="T_4b0bf_row3_col0" class="data row3 col0" >1.000</td>
#       <td id="T_4b0bf_row3_col1" class="data row3 col1" >0.092</td>
#       <td id="T_4b0bf_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_4b0bf_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_4b0bf_row3_col4" class="data row3 col4" >0.135</td>
#       <td id="T_4b0bf_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_4b0bf_row3_col6" class="data row3 col6" >0.000</td>
#       <td id="T_4b0bf_row3_col7" class="data row3 col7" >0.131</td>
#       <td id="T_4b0bf_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_4b0bf_row3_col9" class="data row3 col9" >0.000</td>
#       <td id="T_4b0bf_row3_col10" class="data row3 col10" >0.000</td>
#       <td id="T_4b0bf_row3_col11" class="data row3 col11" >0.004</td>
#       <td id="T_4b0bf_row3_col12" class="data row3 col12" >0.002</td>
#       <td id="T_4b0bf_row3_col13" class="data row3 col13" >0.020</td>
#     </tr>
#     <tr>
#       <th id="T_4b0bf_level0_row4" class="row_heading level0 row4" >f1 (1227)</th>
#       <td id="T_4b0bf_row4_col0" class="data row4 col0" >1.000</td>
#       <td id="T_4b0bf_row4_col1" class="data row4 col1" >0.675</td>
#       <td id="T_4b0bf_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_4b0bf_row4_col3" class="data row4 col3" >0.977</td>
#       <td id="T_4b0bf_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_4b0bf_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_4b0bf_row4_col6" class="data row4 col6" >0.000</td>
#       <td id="T_4b0bf_row4_col7" class="data row4 col7" >0.970</td>
#       <td id="T_4b0bf_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_4b0bf_row4_col9" class="data row4 col9" >0.000</td>
#       <td id="T_4b0bf_row4_col10" class="data row4 col10" >0.000</td>
#       <td id="T_4b0bf_row4_col11" class="data row4 col11" >0.009</td>
#       <td id="T_4b0bf_row4_col12" class="data row4 col12" >0.007</td>
#       <td id="T_4b0bf_row4_col13" class="data row4 col13" >0.052</td>
#     </tr>
#     <tr>
#       <th id="T_4b0bf_level0_row5" class="row_heading level0 row5" >k_r2r_d (0)</th>
#       <td id="T_4b0bf_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_4b0bf_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_4b0bf_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_4b0bf_row5_col3" class="data row5 col3" >0.000</td>
#       <td id="T_4b0bf_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_4b0bf_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_4b0bf_row5_col6" class="data row5 col6" >0.000</td>
#       <td id="T_4b0bf_row5_col7" class="data row5 col7" >0.000</td>
#       <td id="T_4b0bf_row5_col8" class="data row5 col8" >0.000</td>
#       <td id="T_4b0bf_row5_col9" class="data row5 col9" >0.000</td>
#       <td id="T_4b0bf_row5_col10" class="data row5 col10" >0.000</td>
#       <td id="T_4b0bf_row5_col11" class="data row5 col11" >0.000</td>
#       <td id="T_4b0bf_row5_col12" class="data row5 col12" >0.000</td>

# %% [markdown]
# * bin2bin und f1 haben sehr hohe überschneidung (bin2bin ist aber strenger)
# * k_r2r+_min and k_dig+_2 have the exact same results
# * k_r2r+_min and k_c2r+ don't have too high of an overlap
# * ALL of k_r2r+_min/k_dig+_2 (16), k_c2r+ (9) are in b2b
# * ALL of the onlypos-statistics are completely in the respective kappa bin2bin

# %%
generate_comparertable(sample_ctx.obj["featureaxes"]["metrics"], minval=0.1)
# Out:
# <style type="text/css">
# #T_c5556_row0_col2, #T_c5556_row1_col0, #T_c5556_row1_col2, #T_c5556_row1_col4, #T_c5556_row2_col0, #T_c5556_row3_col2, #T_c5556_row4_col0, #T_c5556_row4_col2, #T_c5556_row6_col0, #T_c5556_row6_col1, #T_c5556_row6_col2, #T_c5556_row6_col4, #T_c5556_row7_col0, #T_c5556_row7_col2, #T_c5556_row7_col4, #T_c5556_row9_col2, #T_c5556_row9_col11, #T_c5556_row9_col12, #T_c5556_row10_col0, #T_c5556_row10_col2, #T_c5556_row10_col9, #T_c5556_row10_col11, #T_c5556_row10_col12, #T_c5556_row11_col2, #T_c5556_row12_col2, #T_c5556_row13_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_c5556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5556_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_c5556_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_c5556_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_c5556_level0_col3" class="col_heading level0 col3" >did_converge</th>
#       <th id="T_c5556_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_c5556_level0_col5" class="col_heading level0 col5" >k_r2r_d</th>
#       <th id="T_c5556_level0_col6" class="col_heading level0 col6" >k_r2r_min</th>
#       <th id="T_c5556_level0_col7" class="col_heading level0 col7" >k_b2b</th>
#       <th id="T_c5556_level0_col8" class="col_heading level0 col8" >k_dig</th>
#       <th id="T_c5556_level0_col9" class="col_heading level0 col9" >k_c2r+</th>
#       <th id="T_c5556_level0_col10" class="col_heading level0 col10" >k_r2r+_d</th>
#       <th id="T_c5556_level0_col11" class="col_heading level0 col11" >k_r2r+_min</th>
#       <th id="T_c5556_level0_col12" class="col_heading level0 col12" >k_r2r+_max</th>
#       <th id="T_c5556_level0_col13" class="col_heading level0 col13" >k_dig+_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5556_level0_row0" class="row_heading level0 row0" >accuracy (8500)</th>
#       <td id="T_c5556_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_c5556_row0_col1" class="data row0 col1" >0.049</td>
#       <td id="T_c5556_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_c5556_row0_col3" class="data row0 col3" >0.429</td>
#       <td id="T_c5556_row0_col4" class="data row0 col4" >0.111</td>
#       <td id="T_c5556_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_c5556_row0_col6" class="data row0 col6" >0.010</td>
#       <td id="T_c5556_row0_col7" class="data row0 col7" >0.054</td>
#       <td id="T_c5556_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_c5556_row0_col9" class="data row0 col9" >0.001</td>
#       <td id="T_c5556_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_c5556_row0_col11" class="data row0 col11" >0.198</td>
#       <td id="T_c5556_row0_col12" class="data row0 col12" >0.065</td>
#       <td id="T_c5556_row0_col13" class="data row0 col13" >0.046</td>
#     </tr>
#     <tr>
#       <th id="T_c5556_level0_row1" class="row_heading level0 row1" >precision (420)</th>
#       <td id="T_c5556_row1_col0" class="data row1 col0" >1.000</td>
#       <td id="T_c5556_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_c5556_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_c5556_row1_col3" class="data row1 col3" >0.721</td>
#       <td id="T_c5556_row1_col4" class="data row1 col4" >1.000</td>
#       <td id="T_c5556_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_c5556_row1_col6" class="data row1 col6" >0.200</td>
#       <td id="T_c5556_row1_col7" class="data row1 col7" >0.719</td>
#       <td id="T_c5556_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_c5556_row1_col9" class="data row1 col9" >0.000</td>
#       <td id="T_c5556_row1_col10" class="data row1 col10" >0.000</td>
#       <td id="T_c5556_row1_col11" class="data row1 col11" >0.286</td>
#       <td id="T_c5556_row1_col12" class="data row1 col12" >0.138</td>
#       <td id="T_c5556_row1_col13" class="data row1 col13" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_c5556_level0_row2" class="row_heading level0 row2" >recall (9053)</th>
#       <td id="T_c5556_row2_col0" class="data row2 col0" >0.939</td>
#       <td id="T_c5556_row2_col1" class="data row2 col1" >0.046</td>
#       <td id="T_c5556_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_c5556_row2_col3" class="data row2 col3" >0.406</td>
#       <td id="T_c5556_row2_col4" class="data row2 col4" >0.104</td>
#       <td id="T_c5556_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_c5556_row2_col6" class="data row2 col6" >0.009</td>
#       <td id="T_c5556_row2_col7" class="data row2 col7" >0.051</td>
#       <td id="T_c5556_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_c5556_row2_col9" class="data row2 col9" >0.001</td>
#       <td id="T_c5556_row2_col10" class="data row2 col10" >0.000</td>
#       <td id="T_c5556_row2_col11" class="data row2 col11" >0.201</td>
#       <td id="T_c5556_row2_col12" class="data row2 col12" >0.067</td>
#       <td id="T_c5556_row2_col13" class="data row2 col13" >0.049</td>
#     </tr>
#     <tr>
#       <th id="T_c5556_level0_row3" class="row_heading level0 row3" >did_converge (3675)</th>
#       <td id="T_c5556_row3_col0" class="data row3 col0" >0.993</td>
#       <td id="T_c5556_row3_col1" class="data row3 col1" >0.082</td>
#       <td id="T_c5556_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_c5556_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_c5556_row3_col4" class="data row3 col4" >0.165</td>
#       <td id="T_c5556_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_c5556_row3_col6" class="data row3 col6" >0.019</td>
#       <td id="T_c5556_row3_col7" class="data row3 col7" >0.072</td>
#       <td id="T_c5556_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_c5556_row3_col9" class="data row3 col9" >0.001</td>
#       <td id="T_c5556_row3_col10" class="data row3 col10" >0.001</td>
#       <td id="T_c5556_row3_col11" class="data row3 col11" >0.188</td>
#       <td id="T_c5556_row3_col12" class="data row3 col12" >0.063</td>
#       <td id="T_c5556_row3_col13" class="data row3 col13" >0.034</td>
#     </tr>
#     <tr>
#       <th id="T_c5556_level0_row4" class="row_heading level0 row4" >f1 (943)</th>
#       <td id="T_c5556_row4_col0" class="data row4 col0" >1.000</td>
#       <td id="T_c5556_row4_col1" class="data row4 col1" >0.445</td>
#       <td id="T_c5556_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_c5556_row4_col3" class="data row4 col3" >0.642</td>
#       <td id="T_c5556_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_c5556_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_c5556_row4_col6" class="data row4 col6" >0.089</td>
#       <td id="T_c5556_row4_col7" class="data row4 col7" >0.488</td>
#       <td id="T_c5556_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_c5556_row4_col9" class="data row4 col9" >0.000</td>
#       <td id="T_c5556_row4_col10" class="data row4 col10" >0.000</td>
#       <td id="T_c5556_row4_col11" class="data row4 col11" >0.239</td>
#       <td id="T_c5556_row4_col12" class="data row4 col12" >0.117</td>
#       <td id="T_c5556_row4_col13" class="data row4 col13" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_c5556_level0_row5" class="row_heading level0 row5" >k_r2r_d (0)</th>
#       <td id="T_c5556_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_c5556_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_c5556_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_c5556_row5_col3" class="data row5 col3" >0.000</td>
#       <td id="T_c5556_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_c5556_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_c5556_row5_col6" class="data row5 col6" >0.000</td>
#       <td id="T_c5556_row5_col7" class="data row5 col7" >0.000</td>
#       <td id="T_c5556_row5_col8" class="data row5 col8" >0.000</td>
#       <td id="T_c5556_row5_col9" class="data row5 col9" >0.000</td>
#       <td id="T_c5556_row5_col10" class="data row5

# %%
generate_comparertable(sample_ctx.obj["featureaxes"]["metrics"], minval=0.1, maxval=0.5)
# Out:
# <style type="text/css">
# #T_a934d_row0_col11, #T_a934d_row1_col4, #T_a934d_row2_col11, #T_a934d_row2_col13, #T_a934d_row4_col7, #T_a934d_row6_col1, #T_a934d_row7_col4, #T_a934d_row9_col12, #T_a934d_row10_col9, #T_a934d_row10_col11, #T_a934d_row10_col12, #T_a934d_row11_col12, #T_a934d_row12_col11, #T_a934d_row13_col11 {
#   font-weight: bold;
# }
# </style>
# <table id="T_a934d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a934d_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_a934d_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_a934d_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_a934d_level0_col3" class="col_heading level0 col3" >did_converge</th>
#       <th id="T_a934d_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_a934d_level0_col5" class="col_heading level0 col5" >k_r2r_d</th>
#       <th id="T_a934d_level0_col6" class="col_heading level0 col6" >k_r2r_min</th>
#       <th id="T_a934d_level0_col7" class="col_heading level0 col7" >k_b2b</th>
#       <th id="T_a934d_level0_col8" class="col_heading level0 col8" >k_dig</th>
#       <th id="T_a934d_level0_col9" class="col_heading level0 col9" >k_c2r+</th>
#       <th id="T_a934d_level0_col10" class="col_heading level0 col10" >k_r2r+_d</th>
#       <th id="T_a934d_level0_col11" class="col_heading level0 col11" >k_r2r+_min</th>
#       <th id="T_a934d_level0_col12" class="col_heading level0 col12" >k_r2r+_max</th>
#       <th id="T_a934d_level0_col13" class="col_heading level0 col13" >k_dig+_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a934d_level0_row0" class="row_heading level0 row0" >accuracy (845)</th>
#       <td id="T_a934d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a934d_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_a934d_row0_col2" class="data row0 col2" >0.001</td>
#       <td id="T_a934d_row0_col3" class="data row0 col3" >0.000</td>
#       <td id="T_a934d_row0_col4" class="data row0 col4" >0.001</td>
#       <td id="T_a934d_row0_col5" class="data row0 col5" >0.000</td>
#       <td id="T_a934d_row0_col6" class="data row0 col6" >0.000</td>
#       <td id="T_a934d_row0_col7" class="data row0 col7" >0.000</td>
#       <td id="T_a934d_row0_col8" class="data row0 col8" >0.000</td>
#       <td id="T_a934d_row0_col9" class="data row0 col9" >0.001</td>
#       <td id="T_a934d_row0_col10" class="data row0 col10" >0.000</td>
#       <td id="T_a934d_row0_col11" class="data row0 col11" >0.212</td>
#       <td id="T_a934d_row0_col12" class="data row0 col12" >0.072</td>
#       <td id="T_a934d_row0_col13" class="data row0 col13" >0.084</td>
#     </tr>
#     <tr>
#       <th id="T_a934d_level0_row1" class="row_heading level0 row1" >precision (414)</th>
#       <td id="T_a934d_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_a934d_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_a934d_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_a934d_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_a934d_row1_col4" class="data row1 col4" >0.983</td>
#       <td id="T_a934d_row1_col5" class="data row1 col5" >0.000</td>
#       <td id="T_a934d_row1_col6" class="data row1 col6" >0.188</td>
#       <td id="T_a934d_row1_col7" class="data row1 col7" >0.705</td>
#       <td id="T_a934d_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_a934d_row1_col9" class="data row1 col9" >0.000</td>
#       <td id="T_a934d_row1_col10" class="data row1 col10" >0.000</td>
#       <td id="T_a934d_row1_col11" class="data row1 col11" >0.287</td>
#       <td id="T_a934d_row1_col12" class="data row1 col12" >0.138</td>
#       <td id="T_a934d_row1_col13" class="data row1 col13" >0.007</td>
#     </tr>
#     <tr>
#       <th id="T_a934d_level0_row2" class="row_heading level0 row2" >recall (8)</th>
#       <td id="T_a934d_row2_col0" class="data row2 col0" >0.125</td>
#       <td id="T_a934d_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_a934d_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a934d_row2_col3" class="data row2 col3" >0.000</td>
#       <td id="T_a934d_row2_col4" class="data row2 col4" >0.000</td>
#       <td id="T_a934d_row2_col5" class="data row2 col5" >0.000</td>
#       <td id="T_a934d_row2_col6" class="data row2 col6" >0.000</td>
#       <td id="T_a934d_row2_col7" class="data row2 col7" >0.000</td>
#       <td id="T_a934d_row2_col8" class="data row2 col8" >0.000</td>
#       <td id="T_a934d_row2_col9" class="data row2 col9" >0.000</td>
#       <td id="T_a934d_row2_col10" class="data row2 col10" >0.000</td>
#       <td id="T_a934d_row2_col11" class="data row2 col11" >0.250</td>
#       <td id="T_a934d_row2_col12" class="data row2 col12" >0.000</td>
#       <td id="T_a934d_row2_col13" class="data row2 col13" >0.250</td>
#     </tr>
#     <tr>
#       <th id="T_a934d_level0_row3" class="row_heading level0 row3" >did_converge (0)</th>
#       <td id="T_a934d_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_a934d_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_a934d_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_a934d_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_a934d_row3_col4" class="data row3 col4" >0.000</td>
#       <td id="T_a934d_row3_col5" class="data row3 col5" >0.000</td>
#       <td id="T_a934d_row3_col6" class="data row3 col6" >0.000</td>
#       <td id="T_a934d_row3_col7" class="data row3 col7" >0.000</td>
#       <td id="T_a934d_row3_col8" class="data row3 col8" >0.000</td>
#       <td id="T_a934d_row3_col9" class="data row3 col9" >0.000</td>
#       <td id="T_a934d_row3_col10" class="data row3 col10" >0.000</td>
#       <td id="T_a934d_row3_col11" class="data row3 col11" >0.000</td>
#       <td id="T_a934d_row3_col12" class="data row3 col12" >0.000</td>
#       <td id="T_a934d_row3_col13" class="data row3 col13" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a934d_level0_row4" class="row_heading level0 row4" >f1 (930)</th>
#       <td id="T_a934d_row4_col0" class="data row4 col0" >0.001</td>
#       <td id="T_a934d_row4_col1" class="data row4 col1" >0.438</td>
#       <td id="T_a934d_row4_col2" class="data row4 col2" >0.000</td>
#       <td id="T_a934d_row4_col3" class="data row4 col3" >0.000</td>
#       <td id="T_a934d_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a934d_row4_col5" class="data row4 col5" >0.000</td>
#       <td id="T_a934d_row4_col6" class="data row4 col6" >0.076</td>
#       <td id="T_a934d_row4_col7" class="data row4 col7" >0.481</td>
#       <td id="T_a934d_row4_col8" class="data row4 col8" >0.000</td>
#       <td id="T_a934d_row4_col9" class="data row4 col9" >0.000</td>
#       <td id="T_a934d_row4_col10" class="data row4 col10" >0.000</td>
#       <td id="T_a934d_row4_col11" class="data row4 col11" >0.240</td>
#       <td id="T_a934d_row4_col12" class="data row4 col12" >0.116</td>
#       <td id="T_a934d_row4_col13" class="data row4 col13" >0.008</td>
#     </tr>
#     <tr>
#       <th id="T_a934d_level0_row5" class="row_heading level0 row5" >k_r2r_d (0)</th>
#       <td id="T_a934d_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_a934d_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_a934d_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_a934d_row5_col3" class="data row5 col3" >0.000</td>
#       <td id="T_a934d_row5_col4" class="data row5 col4" >0.000</td>
#       <td id="T_a934d_row5_col5" class="data row5 col5" >nan</td>
#       <td id="T_a934d_row5_col6" class="data row5 col6" >0.000</td>
#       <td id="T_a934d_row5_col7" class="data row5 col7" >0.000</td>
#       <td id="T_a934d_row5_col8" class="data row5 col8" >0.000</td>
#       <td id="T_a934d_row5_col9" class="data row5 col9" >0.000</td>
#       <td id="T_a934d_row5_col10" class="data row5 col10" >0.000</td>
#       <td id="T_a934d_row5_col11" class="data row5 col11" >0.000</td>
#       <td id="T_a934d_row5_col12" class="data row5 col12" >0.000</td>
#       <td id="T_a934d_row5_col13" class="data row5 col13" >0.000</td>
#     </tr>
